# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
movies=pd.read_csv('movies.csv')
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits=pd.read_csv('credits.csv')
credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
rs=pd.merge(movies,credits, on='title')
rs
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4803     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4804       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4805          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4806          0                                                 []
# 4807          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
import ast
def convert(obj):
    L=[]
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
rs['keywords']=rs['keywords'].apply(convert)
rs['genres']=rs['genres'].apply(convert)

rs
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4803     220000                      [Action, Crime, Thriller]
# 4804       9000                              [Comedy, Romance]
# 4805          0             [Comedy, Drama, Romance, TV Movie]
# 4806          0                                             []
# 4807          0                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
def fetch_director(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i ['job'] == "Director":
            L.append(i['name'])
    return L

# %%
rs['crew'] = rs['crew'].apply(fetch_director)
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
rs['overview']=rs['overview'].str.lower()
rs
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4803     220000                      [Action, Crime, Thriller]
# 4804       9000                              [Comedy, Romance]
# 4805          0             [Comedy, Drama, Romance, TV Movie]
# 4806          0                                             []
# 4807          0                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
rs.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3095
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# movie_id                   0
# cast                       0
# crew                       0
# dtype: int64

# %%
rs = rs[['movie_id','title','overview','genres','keywords','cast','crew','budget','popularity']]
rs
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     in the 22nd century, a paraplegic marine is di...
# 1     captain barbossa, long believed to be dead, ha...
# 2     a cryptic message from bond’s past sends him o...
# ...

# %%
rs.dtypes
# Out:
# movie_id        int64
# title          object
# overview       object
# genres         object
# keywords       object
# cast           object
# crew           object
# budget          int64
# popularity    float64
# dtype: object

# %%
rs.isnull().sum()
# Out:
# movie_id      0
# title         0
# overview      3
# genres        0
# keywords      0
# cast          0
# crew          0
# budget        0
# popularity    0
# dtype: int64

# %%
rs.dropna(inplace=True)

# %%
def convert3(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        if counter !=3:
            L.append(i['name'])
            counter += 1
        else:
            break
    return L

# %%
rs['cast'] = rs['cast'].apply(convert3)
rs.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
sns.histplot(data=rs,x='budget')
# Out:
# <Axes: xlabel='budget', ylabel='Count'>

# %%
rs['overview'] = rs['overview'].apply(lambda x: x.split())
rs
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     [in, the, 22nd, century,, a, paraplegic, marin...
# 1     [captain, barbossa,, long, believed, to, be, d...
# 2     [a, cryptic, message, from, bond’s, past, send...
# ...

# %%
rs['overview'][1]
# Out:
# ['captain',
#  'barbossa,',
#  'long',
#  'believed',
#  'to',
#  'be',
#  'dead,',
#  'has',
#  'come',
#  'back',
#  'to',
#  'life',
#  'and',
#  'is',
#  'headed',
#  'to',
#  'the',
#  'edge',
#  'of',
#  'the',
#  'earth',
#  'with',
#  'will',
#  'turner',
#  'and',
#  'elizabeth',
#  'swann.',
#  'but',
#  'nothing',
#  'is',
#  'quite',
#  'as',
#  'it',
#  'seems.']

# %%
rs['genres']=rs['genres'].apply(lambda x:[i.replace(" ","") for i in x]).copy()
rs['keywords']=rs['keywords'].apply(lambda x:[i.replace(" ","") for i in x]).copy()
rs['cast']=rs['cast'].apply(lambda x:[i.replace(" ","") for i in x]).copy()
rs['crew']=rs['crew'].apply(lambda x:[i.replace(" ","") for i in x]).copy()


rs
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     [in, the, 22nd, century,, a, paraplegic, marin...
# 1     [captain, barbossa,, long, believed, to, be, d...
# 2     [a, cryptic, message, from, bond’s, past, send...
# ...

# %%
rs
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     [in, the, 22nd, century,, a, paraplegic, marin...
# 1     [captain, barbossa,, long, believed, to, be, d...
# 2     [a, cryptic, message, from, bond’s, past, send...
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



movies = pd.DataFrame(rs)


genre_counts = [genre for sublist in movies['genres'] for genre in sublist]


plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")
sns.countplot(y=genre_counts, palette="Set3", order=pd.Series(genre_counts).value_counts().index)
plt.title("Genre Distribution in Movies")
plt.xlabel("Count")
plt.ylabel("Genres")
plt.show()

# %%
rs['crew']
# Out:
# 0                              [JamesCameron]
# 1                             [GoreVerbinski]
# 2                                 [SamMendes]
# 3                          [ChristopherNolan]
# 4                             [AndrewStanton]
#                         ...
# 4803                        [RobertRodriguez]
# 4804                            [EdwardBurns]
# 4805                             [ScottSmith]
# 4806                             [DanielHsia]
# 4807    [BrianHerzlinger, JonGunn, BrettWinn]
# Name: crew, Length: 4805, dtype: object

# %%
rs.rename(columns={"crew": "director"}, inplace=True)
rs
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     [in, the, 22nd, century,, a, paraplegic, marin...
# 1     [captain, barbossa,, long, believed, to, be, d...
# 2     [a, cryptic, message, from, bond’s, past, send...
# ...

# %%
rs['genres'].isnull().sum()
# Out:
# 0

# %%
pop= rs.sort_values('popularity', ascending=False)
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))

plt.barh(pop['title'].head(6),pop['popularity'].head(6), align='center',
        color='skyblue')
plt.gca().invert_yaxis()
plt.xlabel("Popularity")
plt.title("Popular Movies")
# Out:
# Text(0.5, 1.0, 'Popular Movies')

# %%
def clean_list_text(lst):

    lst = [word.lower() for word in lst]


    return lst

# %%
rs['genres'] = rs['genres'].apply(clean_list_text)
rs['keywords'] = rs['keywords'].apply(clean_list_text)
rs
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     [in, the, 22nd, century,, a, paraplegic, marin...
# 1     [captain, barbossa,, long, believed, to, be, d...
# 2     [a, cryptic, message, from, bond’s, past, send...
# ...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def more_clean(list):
    list = [words for words in list if not words in stop_words]
    list = [stemmer.stem(words) for words in list]
    return list
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
rs['genres'] = rs['genres'].apply(more_clean)
rs['keywords'] = rs['keywords'].apply(more_clean)
rs['overview'] = rs['overview'].apply(more_clean)


rs
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     [22nd, century,, parapleg, marin, dispatch, mo...
# 1     [captain, barbossa,, long, believ, dead,, come...
# 2     [cryptic, messag, bond’, past, send, trail, un...
# ...

# %%
def to_string(list):
    return ' '.join(list)

# %%
rs['genres'] = rs['genres'].apply(to_string)
rs['keywords'] = rs['keywords'].apply(to_string)
rs['overview'] = rs['overview'].apply(to_string)
rs['cast'] = rs['cast'].apply(to_string)
rs['director'] = rs['director'].apply(to_string)
rs
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                overview  \
# 0     22nd century, parapleg marin dispatch moon pan...
# 1     captain barbossa, long believ dead, come back ...
# 2     cryptic messag bond’ past send trail uncov sin...
# ...

# %%
def get_film_vector(idx, ser, model):
    vector = np.zeros(100)
    word_list = ser.iloc[idx].split()
    for words in word_list:
        vector += model.wv.get_vector(words)

    return vector

# %%
pip install gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models.word2vec import Word2Vec
from scipy import spatial
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
def get_recommendations(title, weights=[1, 1, 1, 1, 1], model=1):
    Ser = weights[0] * rs['genres'] + weights[1] * rs['keywords'] + \
          weights[2] * rs['overview'] + weights[3] * rs['cast'] + \
          weights[4] * rs['director']

    Ser_lda = weights[2] * rs['overview']



    indices = pd.Series(rs.index, index=rs['title']).drop_duplicates()


    if(model == 1):


        tfidf = TfidfVectorizer()
        tfidf_matrix = tfidf.fit_transform(Ser)
        cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

        idx = indices[title]

        sim_scores = enumerate(cosine_sim[idx])
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:11]
        movie_indices = [i[0] for i in sim_scores]

        for vals in rs['title'].iloc[movie_indices].values:
            print(vals)

    elif model == 2:


        data = []
        for summs in Ser.values:
            lst = summs.split()
            data.append(lst)

        vec_model = Word2Vec(data, window=10, min_count=1, workers=4, sg=1)

        # Check if the title is present in the DataFrame
        if title in indices:
            idx = indices.loc[title]
            # Check if the index is within the valid range
            if 0 <= idx < len(rs):
                the_vec = get_film_vector(idx, Ser, vec_model)
                sims = []
                for i in range(len(rs)):
                    vec2 = get_film_vector(i, Ser, vec_model)
                    cossim = 1 - spatial.distance.cosine(the_vec, vec2)
                    sims.append((cossim, i))

                sims = sorted(sims)
                recclist = []
                for cosi, ind in sims[-11:-1]:
                    recclist.append(rs['title'].values[ind])

                recclist.reverse()

                for rex in recclist:
                    print(rex)
            else:
                print(f"Index '{idx}' is out of bounds. Number of rows in DataFrame: {len(rs)}")
        else:
            print(f"Title '{title}' not found in the DataFrame. Titles in DataFrame: {list(rs['title'])}")


    elif model == 3:



        lda_vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
        lda_dtm = lda_vectorizer.fit_transform(Ser_lda)

        lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
        lda_model.fit(lda_dtm)




        def get_film_vector_lda(overview, vectorizer, model):
            lda_vector = model.transform(vectorizer.transform([overview]))[0]
            return lda_vector




        def get_top_movies_lda(lda_vector, n=10):
            # Assuming 'lda_vector' is a column in the DataFrame to store LDA vectors
            rs['lda_vector'] = rs.apply(lambda row: get_film_vector_lda(row['overview'], lda_vectorizer, lda_model), axis=1)


            cosine_sim_lda = cosine_similarity([lda_vector], list(rs['lda_vector']))[0]

            # Get indices of top similar movies
            top_movie_indices_lda = sorted(range(len(cosine_sim_lda)), key=lambda i: cosine_sim_lda[i], reverse=True)[1:n+1]

            # Get the titles of the top movies
            top_movies_lda = rs['title'].iloc[top_movie_indices_lda].values

            return top_movies_lda

        # Check if the title is present in the DataFrame
        if title in indices:
            idx = indices.loc[title]
            # Check if the index is within the valid range
            if 0 <= idx < len(rs):
                lda_vector = get_film_vector_lda(rs['overview'].iloc[idx], lda_vectorizer, lda_model)

                # Get top movies based on LDA vector
                top_movies_lda = get_top_movies_lda(lda_vector, n=10)

                for movie in top_movies_lda:
                    print(movie)
            else:
                print(f"Index '{idx}' is out of bounds. Number of rows in DataFrame: {len(rs)}")
        else:
            print(f"Title '{title}' not found in the DataFrame. Titles in DataFrame: {list(rs['title'])}")

# %%
get_recommendations('Avatar', [1, 1, 1, 1, 1], 2)
# Out:
# Beowulf
# The Host
# Army of Darkness
# Insurgent
# The Host
# Allegiant
# X-Men: The Last Stand
# X-Men Origins: Wolverine
# Interstellar
# Street Fighter

# %%
get_recommendations('Avatar', model=3)
# Out:
# Megiddo: The Omega Code 2
# Alvin and the Chipmunks: Chipwrecked
# Saints and Soldiers
# Crimson Tide
# Schindler's List
# The Exploding Girl
# Stop-Loss
# Dick Tracy
# Legends of the Fall
# Mortdecai
